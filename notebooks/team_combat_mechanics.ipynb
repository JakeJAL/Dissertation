# %%
player1 = [500,300,200,3]
player2 = [800,200,500,1]
player3 = [200,600,300,4]
player4 = [400,300,700,2]

# %%
def fight(a,b,c,d) :
    ta = [a,b]
    tb = [c,d]
    ah = a[0] + (b[2] / a[3]) - (c[1] / a[3])
    return (ah)

# %%
fight(player1,player2,player3,player4)
# Out:
# 466.66666666666663

# %%
player1 = [250,420,780]
player2 = [250,900,140]
player3 = [300,920,0]
player4 = [250,400,760]

# %%
def fight2(a,b,c,d) :
    ta = [a,b]
    tb = [c,d]
    ah = b[0] + (a[2] ) - (c[1])
    return (ah)

# %%
fight2(player1,player2,player3,player4)
# Out:
# 110

# %%
def fight3(a,b,c,d) :
    ta = [a,b]
    tb = [c,d]
    ah = a[0] + (a[2] + b[2] ) - (c[1] + d[1])
    bh = b[0] + (a[2] + b[2] ) - (c[1] + d[1])
    ch = c[0] + (c[2] + d[2] ) - (a[1] + b[1])
    dh = d[0] + (c[2] + d[2] ) - (a[1] + b[1])
    return (ah,bh,ch,dh)

# %%
fight3(player1,player2,player3,player4)
# Out:
# (-150, -150, -260, -310)

# %%
player1 = [250,420,780,3]
player2 = [250,900,140,2]
player3 = [300,920,0,1]
player4 = [250,400,760,4]

# %%
def fight4(a,b,c,d) :
    ta = [a,b]
    tb = [c,d]
    ah = a[0] + (a[2] + (b[2] / a[3]) ) - ((c[1] + d[1]) / a[3])
    bh = b[0] + ((a[2] / b[3]) + b[2] ) - ((c[1] + d[1]) / b[3])
    ch = c[0] + (c[2] + (d[2] / a[3]) ) - ((a[1] + b[1]) /a[3])
    dh = d[0] + ((c[2] / a[3]) + d[2] ) - ((a[1] + b[1])/a[3])
    return (ah,bh,ch,dh)

# %%
fight4(player1,player2,player3,player4)
# Out:
# (636.6666666666665, 120.0, 113.33333333333337, 570.0)

# %%
def fight5(a,b,c,d) :
    ta = [a,b]
    tb = [c,d]
    ah = a[0] + (a[2] + (b[2] / a[3]) ) - ((c[1] + d[1]) / a[3])
    bh = b[0] + ((a[2] / b[3]) + b[2] ) - ((c[1] + d[1]) / b[3])
    ch = c[0] + (c[2] + (d[2] / a[3]) ) - ((a[1] + b[1]) /a[3])
    dh = d[0] + ((c[2] / a[3]) + d[2] ) - ((a[1] + b[1])/a[3])
    
    ah = round(min(a[0],ah))
    bh = round(min(b[0],bh))
    ch = round(min(c[0],ch))
    dh = round(min(d[0],dh))
    
    return (ah,bh,ch,dh)

# %%
fight5(player1,player2,player3,player4)
# Out:
# (250, 120, 113, 250)

# %%
760/60
# Out:
# 12.666666666666666

# %%
player1 = [250,7,13,3]
player2 = [250,15,3,2]
player3 = [300,16,0,1]
player4 = [250,7,13,4]

# %%
def fight6(a,b,c,d) :
    ta = [a,b]
    tb = [c,d]
    ah = a[0] + ((a[2] + b[2]) / a[3]) - ((c[1] + d[1]) / a[3])
    bh = b[0] + ((a[2] + b[2]) / b[3]) - ((c[1] + d[1]) / b[3])
    ch = c[0] + ((c[2] + d[2]) / a[3]) - ((a[1] + b[1]) / a[3])
    dh = d[0] + ((c[2] + d[2]) / a[3]) - ((a[1] + b[1]) / a[3])
    
    ah = round(min(a[0],ah))
    bh = round(min(b[0],bh))
    ch = round(min(c[0],ch))
    dh = round(min(d[0],dh))
    
    return (ah,bh,ch,dh)

# %%
fight6(player1,player2,player3,player4)
# Out:
# (248, 246, 297, 247)

# %%
fight6(player1,player2,player3,player4)[0]
# Out:
# 248

# %%
player1 = [250,7,13,3]
player2 = [250,15,3,2]
player3 = [300,16,0,1]
player4 = [250,7,13,4]

# %%
A = 7

# %%
def match (A,B,C,D):
    #print(a,b,c,d)
    t = 0
    a = A
    b = B
    c = C
    d = D
    while t < 10:
        fight = fight6(a,b,c,d)
        print(fight)
        if fight[0] < 1:
            print ('player 1 died',t)
            a[0] = fight[0]
        if fight[1] < 1:
            print ('player 2 died',t)
            a[0] = fight[0]
        if fight[2] < 1:
            print ('player 3 died',t)
            a[0] = fight[0]
        if fight[3] < 1:
            print ('player 4 died',t)
            a[0] = fight[0]
        else:
            a[0] = fight[0]
            b[0] = fight[1]
            c[0] = fight[2]
            d[0] = fight[3]
        t = t + 1

# %%
print(player1,player2,player3,player4)
# Out:
# [250, 7, 13, 3] [250, 15, 3, 2] [300, 16, 0, 1] [250, 7, 13, 4]

# %%
match(player1,player2,player3,player4)
# Out:
# (248, 246, 297, 247)
# (246, 242, 294, 244)
# (244, 238, 291, 241)
# (242, 234, 288, 238)
# (240, 230, 285, 235)
# (238, 226, 282, 232)
# (236, 222, 279, 229)
# (234, 218, 276, 226)
# (232, 214, 273, 223)
# (230, 210, 270, 220)

# %%
player1 = [250,7,13,3]
player2 = [250,15,3,2]
player3 = [300,16,0,1]
player4 = [250,7,13,4]

# %%
import copy

# %%
stats = {
    'Bap' : [250,7,13,3],
    'Sol' : [250,15,3,2],
    'Torb' : [250,15,3,2],
    'Brig' : [250,15,3,2],
}

# %%
def fight6(a,b,c,d) :
    ta = [a,b]
    tb = [c,d]
    ah = a[0] + ((a[2] + b[2]) / a[3]) - ((c[1] + d[1]) / a[3])
    bh = b[0] + ((a[2] + b[2]) / b[3]) - ((c[1] + d[1]) / b[3])
    ch = c[0] + ((c[2] + d[2]) / a[3]) - ((a[1] + b[1]) / a[3])
    dh = d[0] + ((c[2] + d[2]) / a[3]) - ((a[1] + b[1]) / a[3])
    
    ah = round(min(a[0],ah))
    bh = round(min(b[0],bh))
    ch = round(min(c[0],ch))
    dh = round(min(d[0],dh))
    
    return (ah,bh,ch,dh)

# %%
stats ['Bap'][0]
# Out:
# 250

# %%
def match2 (A,B,C,D):
    t = 0
    a = copy.deepcopy(stats [A])
    b = copy.deepcopy(stats [B])
    c = copy.deepcopy(stats [C])
    d = copy.deepcopy(stats [D])
    print(a,b,c,d)
    print(A,B,C,D)
    while t < 60:
        fight = fight6(a,b,c,d)
        print(fight)
        if fight[0] < 1:
            print ('player 1 died',t)
            a[0] = stats [A][0]
        if fight[1] < 1:
            print ('player 2 died',t)
            b[0] = stats [B][0]
        if fight[2] < 1:
            print ('player 3 died',t)
            c[0] = stats [C][0]
        if fight[3] < 1:
            print ('player 4 died',t)
            d[0] = stats [D][0]
        else:
            a[0] = fight[0]
            b[0] = fight[1]
            c[0] = fight[2]
            d[0] = fight[3]
        t = t + 1

# %%
match2 ('Bap','Sol','Torb','Brig')
# Out:
# [250, 7, 13, 3] [250, 15, 3, 2] [250, 15, 3, 2] [250, 15, 3, 2]
# Bap Sol Torb Brig
# (245, 243, 245, 245)
# (240, 236, 240, 240)
# (235, 229, 235, 235)
# (230, 222, 230, 230)
# (225, 215, 225, 225)
# (220, 208, 220, 220)
# (215, 201, 215, 215)
# (210, 194, 210, 210)
# (205, 187, 205, 205)
# (200, 180, 200, 200)
# (195, 173, 195, 195)
# (190, 166, 190, 190)
# (185, 159, 185, 185)
# (180, 152, 180, 180)
# (175, 145, 175, 175)
# (170, 138, 170, 170)
# (165, 131, 165, 165)
# (160, 124, 160, 160)
# (155, 117, 155, 155)
# (150, 110, 150, 150)
# (145, 103, 145, 145)
# (140, 96, 140, 140)
# (135, 89, 135, 135)
# (130, 82, 130, 130)
# (125, 75, 125, 125)
# (120, 68, 120, 120)
# (115, 61, 115, 115)
# (110, 54, 110, 110)
# (105, 47, 105, 105)
# (100, 40, 100, 100)
# (95, 33, 95, 95)
# (90, 26, 90, 90)
# (85, 19, 85, 85)
# (80, 12, 80, 80)
# (75, 5, 75, 75)
# (70, -2, 70, 70)
# player 2 died 35
# (65, -9, 65, 65)
# player 2 died 36
# (60, -16, 60, 60)
# player 2 died 37
# (55, -23, 55, 55)
# ...

# %%
def match3 (A,B,C,D):
    t = 0
    a = copy.deepcopy(stats [A])
    b = copy.deepcopy(stats [B])
    c = copy.deepcopy(stats [C])
    d = copy.deepcopy(stats [D])
    print(a,b,c,d)
    print(A,B,C,D)
    while t < 60:
        fight = fight6(a,b,c,d)
        #print(fight)
        a[0] = fight[0]
        b[0] = fight[1]
        c[0] = fight[2]
        d[0] = fight[3]
        
        if fight[0] < 1:
            print ('player 1 died',t)
            a[0] = stats [A][0]
        if fight[1] < 1:
            print ('player 2 died',t)
            b[0] = stats [B][0]
        if fight[2] < 1:
            print ('player 3 died',t)
            c[0] = stats [C][0]
        if fight[3] < 1:
            print ('player 4 died',t)
            d[0] = stats [D][0]
        t = t + 1

# %%
match3 ('Bap','Sol','Torb','Brig')
# Out:
# [250, 7, 13, 3] [250, 15, 3, 2] [250, 15, 3, 2] [250, 15, 3, 2]
# Bap Sol Torb Brig
# player 2 died 35
# player 1 died 49
# player 3 died 49
# player 4 died 49

# %%
stats ['Sol'][0]
# Out:
# 250

# %%
stats = {
    'Bap' : [250,7,13,3],
    'Sol' : [250,15,3,2],
    'Torb' : [300,16,0,1],
    'Brig' : [250,7,13,4],
}

# %%
def match4 (A,B,C,D):
    t = 0
    a = copy.deepcopy(stats [A])
    b = copy.deepcopy(stats [B])
    c = copy.deepcopy(stats [C])
    d = copy.deepcopy(stats [D])
    deaths = [0,0,0,0]
    print(a,b,c,d)
    print(A,B,C,D)
    while t < 600:
        fight = fight6(a,b,c,d)
        #print(fight)
        a[0] = fight[0]
        b[0] = fight[1]
        c[0] = fight[2]
        d[0] = fight[3]
        
        if fight[0] < 1:
            print ('player 1 died',t)
            a[0] = stats [A][0]
            deaths [0] = deaths[0] + 1
        if fight[1] < 1:
            print ('player 2 died',t)
            b[0] = stats [B][0]
            deaths [1] = deaths[1] + 1
        if fight[2] < 1:
            print ('player 3 died',t)
            c[0] = stats [C][0]
            deaths [2] = deaths[2] + 1
        if fight[3] < 1:
            print ('player 4 died',t)
            d[0] = stats [D][0]
            deaths [3] = deaths[3] + 1
        t = t + 1
    return deaths

# %%
match4 ('Bap','Sol','Torb','Brig')
# Out:
# [250, 7, 13, 3] [250, 15, 3, 2] [300, 16, 0, 1] [250, 7, 13, 4]
# Bap Sol Torb Brig
# player 2 died 62
# player 4 died 83
# player 3 died 99
# player 1 died 124
# player 2 died 125
# player 4 died 167
# player 2 died 188
# player 3 died 199
# player 1 died 249
# player 2 died 251
# player 4 died 251
# player 3 died 299
# player 2 died 314
# player 4 died 335
# player 1 died 374
# player 2 died 377
# player 3 died 399
# player 4 died 419
# player 2 died 440
# player 1 died 499
# player 3 died 499
# player 2 died 503
# player 4 died 503
# player 2 died 566
# player 4 died 587
# player 3 died 599
# [4, 9, 6, 7]

# %%
def match5 (A,B,C,D):
    t = 0
    a = copy.deepcopy(stats [A])
    b = copy.deepcopy(stats [B])
    c = copy.deepcopy(stats [C])
    d = copy.deepcopy(stats [D])
    deaths = [0,0,0,0]
    list1 = [a,b,c,d]
    list2 = [A,B,C,D]
    #print(a,b,c,d)
    #print(A,B,C,D)
    while t < 600:
        fight = fight6(a,b,c,d)
        #print(fight)
        a[0] = fight[0]
        b[0] = fight[1]
        c[0] = fight[2]
        d[0] = fight[3]
        for i in range (len(fight)):
            if fight[i] < 1:
                print ('player', i+1, 'died',t)
                list1[i][0] = stats [list2[i]][0]
                deaths [i] = deaths[i] + 1
        t = t + 1
    return deaths

# %%
match5 ('Bap','Sol','Torb','Brig')
# Out:
# player 2 died 62
# player 4 died 83
# player 3 died 99
# player 1 died 124
# player 2 died 125
# player 4 died 167
# player 2 died 188
# player 3 died 199
# player 1 died 249
# player 2 died 251
# player 4 died 251
# player 3 died 299
# player 2 died 314
# player 4 died 335
# player 1 died 374
# player 2 died 377
# player 3 died 399
# player 4 died 419
# player 2 died 440
# player 1 died 499
# player 3 died 499
# player 2 died 503
# player 4 died 503
# player 2 died 566
# player 4 died 587
# player 3 died 599
# [4, 9, 6, 7]

# %%
fight
# Out:
# <function __main__.fight(a, b, c, d)>

# %%
fight
# Out:
# <function __main__.fight(a, b, c, d)>

# %%
def match5 (A,B,C,D):
    t = 0
    a = copy.deepcopy(stats [A])
    b = copy.deepcopy(stats [B])
    c = copy.deepcopy(stats [C])
    d = copy.deepcopy(stats [D])
    deaths = [0,0,0,0]
    list1 = [a,b,c,d]
    list2 = [A,B,C,D]
    #print(a,b,c,d)
    #print(A,B,C,D)
    while t < 600:
        fight = fight6(a,b,c,d)
        #print(fight)
        a[0] = fight[0]
        b[0] = fight[1]
        c[0] = fight[2]
        d[0] = fight[3]
        for i in range (len(fight)):
            if fight[i] < 1:
                #print ('player', i+1, 'died',t)
                list1[i][0] = stats [list2[i]][0]
                deaths [i] = deaths[i] + 1
        t = t + 1
    for i in range (len(deaths)):
        print (list2[i], 'died', deaths[i], 'times')
    return deaths

# %%
match5 ('Bap','Sol','Torb','Brig')
# Out:
# Bap died 4 times
# Sol died 9 times
# Torb died 6 times
# Brig died 7 times
# [4, 9, 6, 7]

# %%
stats = {
    'Ana'    : [250,6,12,1],
    'Bap'    : [250,7,13,3],
    'Brig'   : [250,7,13,4],
    'Kiri'   : [225,6,14,3],
    'Sol'    : [250,15,3,2],
    'Torb'   : [300,16,0,1],
    'Pharah' : [225,16,0,4],
    'Junk'   : [250,16,0,4],
}

# %%
('Ana','Bap','Sol','Torb','Brig','Kiri','Pharah','Junk')

# %%
9784/600
# Out:
# 16.30666666666667

# %%
def fight7(A,B,C,D,E,F,G,H) :
    
    
    a = copy.deepcopy(stats [A])
    b = copy.deepcopy(stats [B])
    c = copy.deepcopy(stats [C])
    d = copy.deepcopy(stats [D])
    e = copy.deepcopy(stats [E])
    f = copy.deepcopy(stats [F])
    g = copy.deepcopy(stats [G])
    h = copy.deepcopy(stats [H])
    
    ta = [a,b,c,d]
    tb = [e,f,g,h]
    team1 = []
    
    for i in range(len(ta)):
        ph = (ta[i][0] + ((a[2] + b[2] + c[2] + d[2]) / ta[i][3]) - ((e[1] + f[1] + g[1] + h[1]) / ta[i][3]))
        ph = round(min(ta[i][0],ph))
        team1.append (ph)
    
    
    return team1

# %%
fight7('Ana','Bap','Sol','Torb','Brig','Kiri','Pharah','Junk')
# Out:
# [233, 244, 242, 283]

# %%
(29.7 * 4) + 21
# Out:
# 139.8

# %%
def fight8(a,b,c,d,e,f,g,h) :

    
    ta = [a,b,c,d]
    tb = [e,f,g,h]
    MH = []
    
    for i in range(len(ta)):
        ph = (ta[i][0] + ((a[2] + b[2] + c[2] + d[2]) / ta[i][3]) - ((e[1] + f[1] + g[1] + h[1]) / ta[i][3]))
        ph = round(min(ta[i][0],ph))
        MH.append (ph)
        
    for i in range(len(tb)):
        ph = (tb[i][0] + ((e[2] + f[2] + g[2] + h[2]) / tb[i][3]) - ((a[1] + b[1] + c[1] + d[1]) / tb[i][3]))
        ph = round(min(tb[i][0],ph))
        MH.append (ph)
    
    return MH

# %%
def match6 (A,B,C,D,E,F,G,H):
    t = 0
    a = copy.deepcopy(stats [A])
    b = copy.deepcopy(stats [B])
    c = copy.deepcopy(stats [C])
    d = copy.deepcopy(stats [D])
    e = copy.deepcopy(stats [E])
    f = copy.deepcopy(stats [F])
    g = copy.deepcopy(stats [G])
    h = copy.deepcopy(stats [H])
    
    deaths = [0,0,0,0,0,0,0,0]
    list1 = [a,b,c,d,e,f,g,h]
    list2 = [A,B,C,D,E,F,G,H]
    #print(a,b,c,d)
    #print(A,B,C,D)
    while t < 600:
        fight = fight8(a,b,c,d,e,f,g,h)
        #print(fight)
        
        for i in range (len(list1)):
            list1[i][0] = fight[i]
        
        #a[0] = fight[0]
        #b[0] = fight[1]
        #c[0] = fight[2]
        #d[0] = fight[3]
        
        for i in range (len(fight)):
            if fight[i] < 1:
                #print ('player', i+1, 'died',t)
                list1[i][0] = stats [list2[i]][0]
                deaths [i] = deaths[i] + 1
        t = t + 1
    for i in range (len(deaths)):
        print (list2[i], 'died', deaths[i], 'times')
    return deaths

# %%
match6 ('Ana','Bap','Sol','Junk','Brig','Kiri','Pharah','Torb')
# Out:
# Ana died 40 times
# Bap died 14 times
# Sol died 18 times
# Junk died 9 times
# Brig died 9 times
# Kiri died 15 times
# Pharah died 10 times
# Torb died 33 times
# [40, 14, 18, 9, 9, 15, 10, 33]

# %%
stats = {
    'Ana'    : [250,6,12,1],
    'Bap'    : [250,7,13,3],
    'Brig'   : [250,7,13,4],
    'Kiri'   : [225,6,14,3],
    'Sol'    : [250,15,3,2],
    'Torb'   : [300,16,0,1],
    'Pharah' : [225,16,0,4],
    'Junk'   : [250,16,0,4],
}

# %%
stats['Ana']
# Out:
# [250, 6, 12, 1]

# %%
    'Ana'    : [250,6,12,1],
    'Bap'    : [250,7,13,3],
    'Sol'    : [250,15,3,2],
    'Torb'   : [300,16,0,1],
    
    'Brig'   : [250,7,13,3],
    'Kiri'   : [225,6,14,3],
    'Pharah' : [225,16,0,4],
    'Junk'   : [250,16,0,4],
# Out:
#   File "C:\Users\j92-Lewis\AppData\Local\Temp\ipykernel_7868\497257063.py", line 1
#     'Ana'    : [250,6,12,1],
#     ^
# SyntaxError: illegal target for annotation
